# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

import copy
import cv2
from PIL import Image

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# 최초 수행시에는 다운로드가 진행됩니다. 오래 걸릴 수 있으니 유의해 주세요.  
import urllib3
urllib3.disable_warnings()
(ds_train, ds_test), ds_info = tfds.load(
    'cars196',
    split=['train', 'test'],
    shuffle_files=True,
    with_info=True,
)
# Out:
# Downloading and preparing dataset 1.82 GiB (download: 1.82 GiB, generated: Unknown size, total: 1.82 GiB) to /home/aiffel/tensorflow_datasets/cars196/2.0.0...
# Dl Completed...: |          | 0/0 [00:00<?, ? url/s]
# Dl Size...: |          | 0/0 [00:00<?, ? MiB/s]
# Extraction completed...: |          | 0/0 [00:00<?, ? file/s]
# ---------------------------------------------------------------------------
# DownloadError                             Traceback (most recent call last)
# <ipython-input-3-3137c3d19bb0> in <module>
#       6     split=['train', 'test'],
#       7     shuffle_files=True,
# ----> 8     with_info=True,
#       9 )
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/load.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     329   if download:
#     330     download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 331     dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#     332
#     333   if as_dataset_kwargs is None:
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/dataset_builder.py in download_and_prepare(self, download_dir, download_config)
#     444             self._download_and_prepare(
#     445                 dl_manager=dl_manager,
# --> 446                 download_config=download_config,
#     447             )
#     448
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/dataset_builder.py in _download_and_prepare(self, dl_manager, download_config)
#    1146         optional_pipeline_kwargs = {}
#    1147       split_generators = self._split_generators(  # pylint: disable=unexpected-keyword-arg
# -> 1148           dl_manager, **optional_pipeline_kwargs
#    1149       )
#    1150       # TODO(tfds): Could be removed once all datasets are migrated.
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/image_classification/cars196.py in _split_generators(self, dl_manager)
#     178         'extra': _EXTRA_URL,
#     179         'test_annos':
# --> 180             urllib.parse.urljoin(_URL, 'cars_test_annos_withlabels.mat'),
#     181     })
#     182
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/download/download_manager.py in download_and_extract(self, url_or_urls)
#     635     with self._downloader.tqdm():
#     636       with self._extractor.tqdm():
# --> 637         return _map_promise(self._download_extract, url_or_urls)
#     638
#     639   @property
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/download/download_manager.py in _map_promise(map_fn, all_inputs)
#     775   """Map the function into each element and resolve the promise."""
#     776   all_promises = tf.nest.map_structure(map_fn, all_inputs)  # Apply the function
# --> 777   res = tf.nest.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     778   return res
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/download/download_manager.py in <lambda>(p)
#     775   """Map the function into each element and resolve the promise."""
#     776   all_promises = tf.nest.map_structure(map_fn, all_inputs)  # Apply the function
# --> 777   res = tf.nest.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     778   return res
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/promise/promise.py in get(self, timeout)
#     510         target = self._target()
#     511         self._wait(timeout or DEFAULT_TIMEOUT)
# --> 512         return self._target_settled_value(_raise=True)
#     513
#     514     def _target_settled_value(self, _raise=False):
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/promise/promise.py in _target_settled_value(self, _raise)
#     514     def _target_settled_value(self, _raise=False):
#     515         # type: (bool) -> Any
# --> 516         return self._target()._settled_value(_raise)
#     517
#     518     _value = _reason = _target_settled_value
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/promise/promise.py in _settled_value(self, _raise)
#     224             if _raise:
#     225                 raise_val = self._fulfillment_handler0
# --> 226                 reraise(type(raise_val), raise_val, self._traceback)
#     227             return self._fulfillment_handler0
#     228
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/promise/promise.py in handle_future_result(future)
#     842         # type: (Any) -> None
#     843         try:
# --> 844             resolve(future.result())
#     845         except Exception as e:
#     846             tb = exc_info()[2]
#
# ~/anaconda3/envs/aiffel/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     426                 raise CancelledError()
#     427             elif self._state == FINISHED:
# --> 428                 return self.__get_result()
#     429
#     430             self._condition.wait(timeout)
#
# ~/anaconda3/envs/aiffel/lib/python3.7/concurrent/futures/_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# ~/anaconda3/envs/aiffel/lib/python3.7/concurrent/futures/thread.py in run(self)
#      55
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#      59             self.future.set_exception(exc)
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/download/downloader.py in _sync_download(self, url, destination_path, verify)
#     206       pass
#     207
# --> 208     with _open_url(url, verify=verify) as (response, iter_content):
#     209       fname = _get_filename(response)
#     210       path = os.path.join(destination_path, fname)
#
# ~/anaconda3/envs/aiffel/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/download/downloader.py in _open_with_requests(url, **kwargs)
#     269       url = _get_drive_url(url, session)
#     270     with session.get(url, stream=True, **kwargs) as response:
# --> 271       _assert_status(response)
#     272       yield (response, response.iter_content(chunk_size=io.DEFAULT_BUFFER_SIZE))
#     273
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow_datasets/core/download/downloader.py in _assert_status(response)
#     301   if response.status_code != 200:
#     302     raise DownloadError('Failed to get url {}. HTTP code: {}.'.format(
# --> 303         response.url, response.status_code))
#
# DownloadError: Failed to get url http://ai.stanford.edu/~jkrause/car196/cars_test_annos_withlabels.mat%EF%BB%BF. HTTP code: 404.
