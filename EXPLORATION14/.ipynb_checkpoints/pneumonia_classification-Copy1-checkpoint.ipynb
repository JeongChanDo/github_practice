# %% [markdown]
# # 1. setup configuration
# ## 1.1 Load Libraries

# %%
import re
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 1.2 set variables

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
BATCH_SIZE = 8
IMAGE_SIZE = [180, 180]
EPOCHS = 25

# %% [markdown]
# # 2. Prepare Dataset
# ## 2.1 read file names

# %%
train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*'))

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %% [markdown]
# ## 2.2 split file names and count normal/pneumonia

# %%
filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*')))

train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)
print(len(train_filenames))
print(len(val_filenames))

COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal count in ts: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia count in ts: " + str(COUNT_PNEUMONIA))
# Out:
# 4185
# 1047
# Normal count in ts: 1086
# Pneumonia count in ts: 3099

# %% [markdown]
# ## 2.3 get datasets, counts, and class names

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training imgs count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("valid imgs count: " + str(VAL_IMG_COUNT))


CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/chest_xray/train/*"))])
print(CLASS_NAMES)
# Out:
# Training imgs count: 4185
# valid imgs count: 1047
# ['PNEUMONIA' 'NORMAL']

# %% [markdown]
# ## 2.4 load images

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"

def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %% [markdown]
# ## 2.5 data preprocessing

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image) 
    return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.map(
            augment,
            num_parallel_calls=2
        )

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# # 3. Visualize batch data

# %%
image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(8):
        ax = plt.subplot(4,4,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# # 4. CNN Modeling
# ## 4.1 Modeling

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

def balance_weight():
    weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
    weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

    class_weight = {0: weight_for_0, 1: weight_for_1}

    print('Weight for class 0: {:.2f}'.format(weight_for_0))
    print('Weight for class 1: {:.2f}'.format(weight_for_1))
    return weight_for_0, weight_for_1

# %% [markdown]
# ## 4.2 CNN model learning

# %%
weight_for_0, weight_for_1 = balance_weight()
class_weight = {0: weight_for_0, 1: weight_for_1}

with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Weight for class 0: 1.93
# Weight for class 1: 0.68
# Epoch 1/30
# 523/523 [==============================] - 49s 93ms/step - loss: 0.4515 - accuracy: 0.7880 - precision: 0.9406 - recall: 0.7618 - val_loss: 0.5793 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 1.0000
# Epoch 2/30
# 523/523 [==============================] - 41s 77ms/step - loss: 0.3598 - accuracy: 0.8317 - precision: 0.9569 - recall: 0.8092 - val_loss: 0.2053 - val_accuracy: 0.9106 - val_precision: 0.9113 - val_recall: 0.9756
# Epoch 3/30
# 523/523 [==============================] - 40s 77ms/step - loss: 0.3334 - accuracy: 0.8533 - precision: 0.9563 - recall: 0.8403 - val_loss: 0.1787 - val_accuracy: 0.9212 - val_precision: 0.9678 - val_recall: 0.9256
# Epoch 4/30
# 523/523 [==============================] - 40s 76ms/step - loss: 0.3389 - accuracy: 0.8456 - precision: 0.9531 - recall: 0.8325 - val_loss: 0.7861 - val_accuracy: 0.6317 - val_precision: 1.0000 - val_recall: 0.5090
# Epoch 5/30
# 523/523 [==============================] - 40s 76ms/step - loss: 0.2897 - accuracy: 0.8733 - precision: 0.9662 - recall: 0.8589 - val_loss: 0.1647 - val_accuracy: 0.9529 - val_precision: 0.9867 - val_recall: 0.9499
# Epoch 6/30
# 523/523 [==============================] - 39s 76ms/step - loss: 0.2858 - accuracy: 0.8731 - precision: 0.9666 - recall: 0.8583 - val_loss: 0.1325 - val_accuracy: 0.9596 - val_precision: 0.9843 - val_recall: 0.9615
# Epoch 7/30
# 523/523 [==============================] - 36s 70ms/step - loss: 0.2751 - accuracy: 0.8836 - precision: 0.9674 - recall: 0.8723 - val_loss: 0.6961 - val_accuracy: 0.7673 - val_precision: 0.7627 - val_recall: 1.0000
# Epoch 20/30
# 523/523 [==============================] - 36s 69ms/step - loss: 0.2120 - accuracy: 0.9094 - precision: 0.9735 - recall: 0.9021 - val_loss: 0.0805 - val_accuracy: 0.9712 - val_precision: 0.9710 - val_recall: 0.9910
# Epoch 21/30
# 523/523 [==============================] - 36s 70ms/step - loss: 0.1942 - accuracy: 0.9218 - precision: 0.9786 - recall: 0.9144 - val_loss: 0.1220 - val_accuracy: 0.9462 - val_precision: 0.9959 - val_recall: 0.9321
# Epoch 22/30
# 523/523 [==============================] - 37s 70ms/step - loss: 0.1668 - accuracy: 0.9285 - precision: 0.9815 - recall: 0.9211 - val_loss: 0.1122 - val_accuracy: 0.9558 - val_precision: 0.9946 - val_recall: 0.9459
# Epoch 23/30
# 523/523 [==============================] - 36s 69ms/step - loss: 0.1441 - accuracy: 0.9393 - precision: 0.9873 - recall: 0.9298 - val_loss: 0.0702 - val_accuracy: 0.9769 - val_precision: 0.9922 - val_recall: 0.9769
# Epoch 24/30
# 523/523 [==============================] - 36s 69ms/step - loss: 0.1391 - accuracy: 0.9448 - precision: 0.9854 - recall: 0.9393 - val_loss: 0.0690 - val_accuracy: 0.9779 - val_precision: 0.9922 - val_recall: 0.9781
# Epoch 25/30
# 523/523 [==============================] - 37s 70ms/step - loss: 0.2493 - accuracy: 0.8932 - precision: 0.9726 - recall: 0.8806 - val_loss: 0.1121 - val_accuracy: 0.9596 - val_precision: 0.9804 - val_recall: 0.9653
# Epoch 26/30
# 523/523 [==============================] - 36s 70ms/step - loss: 0.1979 - accuracy: 0.9173 - precision: 0.9778 - recall: 0.9090 - val_loss: 0.0988 - val_accuracy: 0.9712 - val_precision: 0.9722 - val_recall: 0.9897
# Epoch 27/30
# 523/523 [==============================] - 37s 70ms/step - loss: 0.1782 - accuracy: 0.9316 - precision: 0.9825 - recall: 0.9242 - val_loss: 0.1075 - val_accuracy: 0.9548 - val_precision: 0.9854 - val_recall: 0.9538
# Epoch 28/30
# 523/523 [==============================] - 37s 70ms/step - loss: 0.1763 - accuracy: 0.9293 - precision: 0.9831 - recall: 0.9202 - val_loss: 1.3657 - val_accuracy: 0.8827 - val_precision: 0.8695 - val_recall: 0.9923
# Epoch 29/30
# 523/523 [==============================] - 37s 70ms/step - loss: 0.1833 - accuracy: 0.9230 - precision: 0.9830 - recall: 0.9119 - val_loss: 0.2165 - val_accuracy: 0.8981 - val_precision: 0.9985 - val_recall: 0.8656
# Epoch 30/30
# 523/523 [==============================] - 36s 70ms/step - loss: 0.1765 - accuracy: 0.9273 - precision: 0.9834 - recall: 0.9174 - val_loss: 0.1274 - val_accuracy: 0.9375 - val_precision: 0.9958 - val_recall: 0.9204

# %% [markdown]
# ## 4.3 CNN model Evaluation

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 78/78 [==============================] - 4s 50ms/step - loss: 0.4745 - accuracy: 0.8397 - precision: 0.8266 - recall: 0.9410
