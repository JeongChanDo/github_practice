# %% [markdown]
# # 1. setup configuration
# ## 1.1 Load Libraries

# %%
import re
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 1.2 set variables

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
BATCH_SIZE = 8
IMAGE_SIZE = [180, 180]
EPOCHS = 25

# %% [markdown]
# # 2. Prepare Dataset
# ## 2.1 read file names

# %%
train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*'))

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %% [markdown]
# ## 2.2 split file names and count normal/pneumonia

# %%
filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*')))

train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)
print(len(train_filenames))
print(len(val_filenames))

COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal count in ts: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia count in ts: " + str(COUNT_PNEUMONIA))
# Out:
# 4185
# 1047
# Normal count in ts: 1091
# Pneumonia count in ts: 3094

# %% [markdown]
# ## 2.3 get datasets, counts, and class names

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training imgs count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("valid imgs count: " + str(VAL_IMG_COUNT))


CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/chest_xray/train/*"))])
print(CLASS_NAMES)
# Out:
# Training imgs count: 4185
# valid imgs count: 1047
# ['PNEUMONIA' 'NORMAL']

# %% [markdown]
# ## 2.4 load images

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"

def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %% [markdown]
# ## 2.5 data preprocessing

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image) 
    return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.map(
            augment,
            num_parallel_calls=2
        )

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# # 3. Visualize batch data

# %%
image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(8):
        ax = plt.subplot(4,4,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# # 4. CNN Modeling
# ## 4.1 Modeling

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

def balance_weight():
    weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
    weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

    class_weight = {0: weight_for_0, 1: weight_for_1}

    print('Weight for class 0: {:.2f}'.format(weight_for_0))
    print('Weight for class 1: {:.2f}'.format(weight_for_1))
    return weight_for_0, weight_for_1

# %% [markdown]
# ## 4.2 CNN model learning

# %%
weight_for_0, weight_for_1 = balance_weight()
class_weight = {0: weight_for_0, 1: weight_for_1}

with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Weight for class 0: 1.92
# Weight for class 1: 0.68
# Epoch 1/25
# 523/523 [==============================] - 44s 84ms/step - loss: 0.4908 - accuracy: 0.7533 - precision: 0.9260 - recall: 0.7243 - val_loss: 0.7394 - val_accuracy: 0.7548 - val_precision: 0.7548 - val_recall: 1.0000
# Epoch 2/25
# 523/523 [==============================] - 39s 74ms/step - loss: 0.3366 - accuracy: 0.8542 - precision: 0.9579 - recall: 0.8396 - val_loss: 0.3096 - val_accuracy: 0.8519 - val_precision: 0.9984 - val_recall: 0.8043
# Epoch 3/25
# 523/523 [==============================] - 39s 74ms/step - loss: 0.2732 - accuracy: 0.8843 - precision: 0.9688 - recall: 0.8717 - val_loss: 0.1913 - val_accuracy: 0.9308 - val_precision: 0.9931 - val_recall: 0.9146
# Epoch 4/25
# 523/523 [==============================] - 41s 78ms/step - loss: 0.2625 - accuracy: 0.8891 - precision: 0.9653 - recall: 0.8816 - val_loss: 0.1288 - val_accuracy: 0.9442 - val_precision: 0.9764 - val_recall: 0.9490
# Epoch 5/25
# 523/523 [==============================] - 41s 78ms/step - loss: 0.2379 - accuracy: 0.8996 - precision: 0.9734 - recall: 0.8885 - val_loss: 0.1382 - val_accuracy: 0.9606 - val_precision: 0.9856 - val_recall: 0.9617
# Epoch 6/25
# 523/523 [==============================] - 41s 79ms/step - loss: 0.2751 - accuracy: 0.8836 - precision: 0.9627 - recall: 0.8766 - val_loss: 0.1768 - val_accuracy: 0.9240 - val_precision: 0.9876 - val_recall: 0.9107
# Epoch 7/25
# 523/523 [==============================] - 40s 77ms/step - loss: 0.2862 - accuracy: 0.8750 - precision: 0.9622 - recall: 0.8648 - val_loss: 0.3351 - val_accuracy: 0.8692 - val_precision: 0.8562 - val_recall: 0.9936
# Epoch 8/25
# 523/523 [==============================] - 44s 83ms/step - loss: 0.3205 - accuracy: 0.8607 - precision: 0.9628 - recall: 0.8443 - val_loss: 0.5269 - val_accuracy: 0.7548 - val_precision: 1.0000 - val_recall: 0.6747
# Epoch 9/25
# 523/523 [==============================] - 41s 79ms/step - loss: 0.2864 - accuracy: 0.8774 - precision: 0.9681 - recall: 0.8625 - val_loss: 0.1805 - val_accuracy: 0.9308 - val_precision: 0.9972 - val_recall: 0.9106
# Epoch 10/25
# 523/523 [==============================] - 42s 79ms/step - loss: 0.2502 - accuracy: 0.8917 - precision: 0.9718 - recall: 0.8792 - val_loss: 0.2409 - val_accuracy: 0.8962 - val_precision: 0.9985 - val_recall: 0.8635
# Epoch 11/25
# 523/523 [==============================] - 40s 77ms/step - loss: 0.2383 - accuracy: 0.9027 - precision: 0.9739 - recall: 0.8923 - val_loss: 0.0914 - val_accuracy: 0.9731 - val_precision: 0.9859 - val_recall: 0.9783
# Epoch 12/25
# 523/523 [==============================] - 41s 78ms/step - loss: 0.2325 - accuracy: 0.8996 - precision: 0.9718 - recall: 0.8901 - val_loss: 0.2514 - val_accuracy: 0.9029 - val_precision: 0.9830 - val_recall: 0.8865
# Epoch 13/25
# 523/523 [==============================] - 41s 79ms/step - loss: 0.2368 - accuracy: 0.9011 - precision: 0.9728 - recall: 0.8910 - val_loss: 0.1392 - val_accuracy: 0.9519 - val_precision: 0.9508 - val_recall: 0.9872
# Epoch 14/25
# 523/523 [==============================] - 41s 78ms/step - loss: 0.2080 - accuracy: 0.9202 - precision: 0.9815 - recall: 0.9091 - val_loss: 0.1620 - val_accuracy: 0.9423 - val_precision: 0.9321 - val_recall: 0.9962
# Epoch 15/25
# 523/523 [==============================] - 42s 79ms/step - loss: 0.2125 - accuracy: 0.9171 - precision: 0.9735 - recall: 0.9128 - val_loss: 0.1087 - val_accuracy: 0.9596 - val_precision: 0.9894 - val_recall: 0.9566
# Epoch 16/25
# 523/523 [==============================] - 42s 80ms/step - loss: 0.2040 - accuracy: 0.9166 - precision: 0.9761 - recall: 0.9095 - val_loss: 0.3220 - val_accuracy: 0.8683 - val_precision: 0.8551 - val_recall: 0.9936
# Epoch 17/25
# 523/523 [==============================] - 42s 81ms/step - loss: 0.1987 - accuracy: 0.9197 - precision: 0.9795 - recall: 0.9105 - val_loss: 0.1034 - val_accuracy: 0.9673 - val_precision: 0.9771 - val_recall: 0.9796
# Epoch 18/25
# 523/523 [==============================] - 42s 81ms/step - loss: 0.2102 - accuracy: 0.9161 - precision: 0.9764 - recall: 0.9084 - val_loss: 0.1187 - val_accuracy: 0.9587 - val_precision: 0.9907 - val_recall: 0.9540
# Epoch 19/25
# 523/523 [==============================] - 42s 81ms/step - loss: 0.1885 - accuracy: 0.9197 - precision: 0.9802 - recall: 0.9098 - val_loss: 0.0816 - val_accuracy: 0.9683 - val_precision: 0.9921 - val_recall: 0.9655
# Epoch 20/25
# 523/523 [==============================] - 42s 81ms/step - loss: 0.1729 - accuracy: 0.9350 - precision: 0.9846 - recall: 0.9267 - val_loss: 0.1005 - val_accuracy: 0.9596 - val_precision: 0.9973 - val_recall: 0.9490
# Epoch 21/25
# 523/523 [==============================] - 42s 80ms/step - loss: 0.1682 - accuracy: 0.9343 - precision: 0.9816 - recall: 0.9286 - val_loss: 0.5411 - val_accuracy: 0.8404 - val_precision: 0.8823 - val_recall: 0.9093
# Epoch 22/25
# 523/523 [==============================] - 42s 81ms/step - loss: 0.2027 - accuracy: 0.9163 - precision: 0.9790 - recall: 0.9062 - val_loss: 0.3626 - val_accuracy: 0.8202 - val_precision: 0.9983 - val_recall: 0.7625
# Epoch 23/25
# 523/523 [==============================] - 43s 81ms/step - loss: 0.1901 - accuracy: 0.9218 - precision: 0.9792 - recall: 0.9136 - val_loss: 0.0974 - val_accuracy: 0.9615 - val_precision: 0.9831 - val_recall: 0.9655
# Epoch 24/25
# 523/523 [==============================] - 42s 80ms/step - loss: 0.1953 - accuracy: 0.9223 - precision: 0.9786 - recall: 0.9151 - val_loss: 0.0929 - val_accuracy: 0.9635 - val_precision: 0.9844 - val_recall: 0.9668
# Epoch 25/25
# 523/523 [==============================] - 41s 78ms/step - loss: 0.1948 - accuracy: 0.9245 - precision: 0.9803 - recall: 0.9162 - val_loss: 0.0734 - val_accuracy: 0.9740 - val_precision: 0.9922 - val_recall: 0.9732

# %% [markdown]
# ## 4.3 CNN model Evaluation

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 78/78 [==============================] - 4s 51ms/step - loss: 0.6614 - accuracy: 0.8029 - precision: 0.7633 - recall: 0.9923
